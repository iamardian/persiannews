# %%
import pandas as pd
import re

# %%
df = pd.read_csv("./dev.csv", sep='\t')

# %%
def word_count(str):
    return len(str.split())

# %%
def char_count(str):
    return len(str)

# %%
def sentence_count(str):
    return len(str.split('.'))

# %%
def number_count(str):
    return len(re.findall('[0-9]+', str))

# %%
def en_word_count(str):
    return len(re.findall('[a-zA-Z]+', str))

# %%
lbl = df.label_id.to_list()
lbl = list(set(lbl))

# %%
label = []
char_len = []
word = []
sentence = []
number = []
en = []
for lb in lbl:
    data = df[df['label_id'] == lb]
    for j, str in enumerate(data):
        label.append(lb)
        char_len.append(char_count(str))
        word.append(word_count(str))
        sentence.append(sentence_count(str))
        number.append(number_count(str))
        en.append(en_word_count(str))
        # print(f"label : {lb},len : {char_count(str)}, word : {word_count(str)}, sentence : {sentence_count(str)}, number : {number_count(str)}, en : {en_word_count(str)}")

report = pd.DataFrame({
    "label": label,
    "char_len": char_len,
    "word": word,
    "sentence": sentence,
    "number": number,
    "en": en
})
report
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1133106/273549119.py in <module>
#       7 for lb in lbl:
#       8     data = df[df['label_id'] == lb]
# ----> 9     for j, str in enumerate(data.to_list()):
#      10         label.append(lb)
#      11         char_len.append(char_count(str))
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_list'
